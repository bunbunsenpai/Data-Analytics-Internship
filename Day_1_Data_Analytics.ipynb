# %% [markdown]
# Gaurav Singh
# 38/B
# KSE

# %%
import pandas as pd

# %%
import numpy as np

# %%
num=np.array([34,12,37,65,48,79,15])

# %%
num
# Out:
# array([34, 12, 37, 65, 48, 79, 15])

# %%
type(num)
# Out:
# numpy.ndarray

# %%
num.dtype
# Out:
# dtype('int64')

# %%
num[2]
# Out:
# 37

# %%
s=pd.Series([45,12,38,75,19,36])

# %%
s
# Out:
# 0    45
# 1    12
# 2    38
# 3    75
# 4    19
# 5    36
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
pandas.core.series.Series
# Out:
# pandas.core.series.Series

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.size
# Out:
# 6

# %%
s.shape
# Out:
# (6,)

# %%
s=pd.Series([45,12,38,75,19,36] , index=range(100,106))

# %%
s
# Out:
# 100    45
# 101    12
# 102    38
# 103    75
# 104    19
# 105    36
# dtype: int64

# %%
s[105]
# Out:
# 36

# %%
r=pd.Series([1,2,3,4,5])
n=pd.Series(['prem','g','d','f','y'])
m=pd.Series([11,32,43,14,55])

# %%
df=pd.DataFrame({'roll':r,
                 'Name':n,
                 'Marks':m,})

# %%
df
# Out:
#    roll  Name  Marks
# 0     1  prem     11
# 1     2     g     32
# 2     3     d     43
# 3     4     f     14
# 4     5     y     55

# %%
df.shape
# Out:
# (5, 3)

# %%
df.size
# Out:
# 15

# %%
df.dtypes
# Out:
# roll      int64
# Name     object
# Marks     int64
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('/content/student (1).csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
df1 = pd.read_csv('/content/student1.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
cols=['A','B','C','D','E']

# %%
df1 = pd.read_csv('student1.csv', names=cols)

# %%
df3 = pd.read_csv('/content/student3.csv')

# %%
df3
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df3 = pd.read_csv('/content/student3.csv' , sep='\t')
df3
# Out:
#    roll,name,class,marks ,age
# 0          1,anil,TE,56.77,22
# 1          2,amit,TE,59.77,21
# 2        3,aniket,BE,76.88,19
# 3       4,ajinkya,TE,69.66,20
# 4            5,asha,TE,63.28,
# 5             6,ayesha,BE,,20
# 6          7,amar,BE,65.34,19
# 7         8,Amita,be,68.33,23
# 8          9,amol,TE,56.75,20
# 9          9,amol,TE,56.75,20
# 10         10,anmol,BE,78.66,
# 11           11,surbhi,TE,,23
# 12       12,Sujay,TE,74.12,22
# 13     13,subhash,be,88.45,21
# 14        14,sachin,,59.33,21
# 15     15,shalini,TE,63.45,20

# %%
df2=pd.read_csv('https://gist.githubusercontent.com/justimchung/9b98c69b30600a46daa6d2e827c31b56/raw/4b1f08ba9b00a2fcd3f7ced9cf9e59062f489c3a/student.csv')

# %%
df2
# Out:
#   Unnamed: 0    Name  height  weight  sex       bdate       city major
# 0   s1234567   Peter   175.0   70.45    1   1980/4/30     Tainan  CSIE
# 1   e1234567    Mary   163.0   55.00    2  1981/12/21     Taipei    EE
# 2   f1357689    John   180.4   80.30    1   1980/5/30     Tainan  Stat
# 3   e1374659   Keven   182.5   77.60    1  1980/11/19     Taipei    EE
# 4   s7758347    JoJo   170.3   50.30    2   1980/1/27     Taipei  CSIE
# 5   s1334987   Emily   168.5   53.60    2  1982/10/13  Kaohsiung  CSIE
# 6   e1384726  Ubuntu   177.0   68.30    1    1981/7/6  Kaohsiung    EE

# %%
dfx=pd.read_excel('student.xlsx')

# %%
dfx
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.tail(3)
# Out:
#    roll   name class  marks  age
# 7     8  amita    BE  68.33   23
# 8     9   amol    TE  56.75   20
# 9    10  anmol    BE  78.66   21
