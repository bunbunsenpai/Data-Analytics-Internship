# %% [markdown]
# <a href="https://colab.research.google.com/github/bunbunsenpai/Data-Analytics-Internship/blob/main/Day_2_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gaurav Singh
# 38/B
# KSE

# %%
import pandas as pd
import numpy as np
num=np.array([34,12,37,65,48,79,15])
num
# Out:
# array([34, 12, 37, 65, 48, 79, 15])

# %%
type(num)
# Out:
# numpy.ndarray

# %%
df=pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
x = df.iloc[4:9,1:4]
print (x)
# Out:
#      name class  marks
# 4    asha    TE  63.28
# 5  ayesha    BE  49.55
# 6    amar    BE  65.34
# 7   amita    BE  68.33
# 8    amol    TE  56.75

# %%
x = df.iloc[:9,1:4]
x
# Out:
#       name class  marks
# 0     anil    TE  56.77
# 1     amit    TE  59.77
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33
# 8     amol    TE  56.75

# %%
x = df.iloc[4:,1:4]
x
# Out:
#      name class  marks
# 4    asha    TE  63.28
# 5  ayesha    BE  49.55
# 6    amar    BE  65.34
# 7   amita    BE  68.33
# 8    amol    TE  56.75
# 9   anmol    BE  78.66

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[[5,7,2,1],[1,3]]
# Out:
#      name  marks
# 5  ayesha  49.55
# 7   amita  68.33
# 2  aniket  76.88
# 1    amit  59.77

# %%
df.iloc[5,:]
# Out:
# roll          6
# name     ayesha
# class        BE
# marks     49.55
# age          20
# Name: 5, dtype: object

# %%
df.iloc[5]
# Out:
# roll          6
# name     ayesha
# class        BE
# marks     49.55
# age          20
# Name: 5, dtype: object

# %%
df.iloc[:, 3]
# Out:
# 0    56.77
# 1    59.77
# 2    76.88
# 3    69.66
# 4    63.28
# 5    49.55
# 6    65.34
# 7    68.33
# 8    56.75
# 9    78.66
# Name: marks, dtype: float64

# %%
df[['name']]
# Out:
#       name
# 0     anil
# 1     amit
# 2   aniket
# 3  ajinkya
# 4     asha
# 5   ayesha
# 6     amar
# 7    amita
# 8     amol
# 9    anmol

# %%
df[['name','marks','age']]
# Out:
#       name  marks  age
# 0     anil  56.77   22
# 1     amit  59.77   21
# 2   aniket  76.88   19
# 3  ajinkya  69.66   20
# 4     asha  63.28   20
# 5   ayesha  49.55   20
# 6     amar  65.34   19
# 7    amita  68.33   23
# 8     amol  56.75   20
# 9    anmol  78.66   21

# %%
df.name
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.marks
# Out:
# 0    56.77
# 1    59.77
# 2    76.88
# 3    69.66
# 4    63.28
# 5    49.55
# 6    65.34
# 7    68.33
# 8    56.75
# 9    78.66
# Name: marks, dtype: float64

# %%
df. iloc[list(range(5))+list(range(6,10))]
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop(5)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
list(range(5))+list (range(6,10))
# Out:
# [0, 1, 2, 3, 4, 6, 7, 8, 9]

# %%
df.drop([5,8,2])
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
df.drop('class', axis=1)
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %%
df.drop(['class','age'], axis=1)
# Out:
#    roll     name  marks
# 0     1     anil  56.77
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28
# 5     6   ayesha  49.55
# 6     7     amar  65.34
# 7     8    amita  68.33
# 8     9     amol  56.75
# 9    10    anmol  78.66

# %%
####### Functions/Methods

# %%
df['marks'].mean()
# Out:
# 64.499

# %%
df['marks'].max()
# Out:
# 78.66

# %%
df['marks'].min()
# Out:
# 49.55

# %%
df['marks'].sum()
# Out:
# 644.9899999999999

# %%
df['name'].sum()
# Out:
# 'anilamitaniketajinkyaashaayeshaamaramitaamolanmol'

# %%
df['name'].min()
# Out:
# 'ajinkya'

# %%
df['name'].max()
# Out:
# 'ayesha'

# %%
df['class']. value_counts()
# Out:
# class
# TE    5
# BE    5
# Name: count, dtype: int64

# %%
df['age']. value_counts()
# Out:
# age
# 20    4
# 21    2
# 19    2
# 22    1
# 23    1
# Name: count, dtype: int64

# %%
df['name']. value_counts()
# Out:
# name
# anil       1
# amit       1
# aniket     1
# ajinkya    1
# asha       1
# ayesha     1
# amar       1
# amita      1
# amol       1
# anmol      1
# Name: count, dtype: int64

# %%
df['age']. mode()
# Out:
# 0    20
# Name: age, dtype: int64

# %%
df.min()
# Out:
# roll           1
# name     ajinkya
# class         BE
# marks      49.55
# age           19
# dtype: object

# %%
df.mean(numeric_only=True)
# Out:
# roll      5.500
# marks    64.499
# age      20.500
# dtype: float64

# %%
df.mean(numeric_only=True,axis=1)
# Out:
# 0    26.590000
# 1    27.590000
# 2    32.960000
# 3    31.220000
# 4    29.426667
# 5    25.183333
# 6    30.446667
# 7    33.110000
# 8    28.583333
# 9    36.553333
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 528.0+ bytes

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000
